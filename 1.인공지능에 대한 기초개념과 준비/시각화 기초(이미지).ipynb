# %% [markdown]
# # **이미지 시각화**
#
# ## **package 불러오기**

# %%
import numpy as np

from PIL import Image

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ----
#
# ## **이미지 파일 열기**

# %%
path = 'C:/Users/DCU/Desktop/Git-cum/Fast_Cappus_-DeepLearning-AI/인공지능에 대한 기초개념과 준비/image/배수지.jpg'

image_pil = Image.open(path)
image = np.array(image_pil)

# %%
image.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ---
# ## **이미지 들여다 보기**

# %%
image.shape
# Out:
# (512, 512, 3)

# %%
np.min(image), np.max(image)
# Out:
# (0, 255)

# %% [markdown]
# 이미지를 열기 전에 shape 및 min,max를 통해서 이미지의 range 확인 필요
#
# ---
#
# ## **그래프로 시각화하기**

# %%
plt.hist(image.ravel(),256, [0, 256])
plt.show()

# %% [markdown]
# ## **그림 나타내기**

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ## **이미지 흑백으로 열기**

# %%
path
# Out:
# 'C:/Users/DCU/Desktop/Git-cum/Fast_Cappus_-DeepLearning-AI/인공지능에 대한 기초개념과 준비/image/배수지.jpg'

# %%
image_pil = Image.open(path).convert('L')
image_bw = np.array(image_pil)

# %%
image_bw.shape
# Out:
# (512, 512)

# %% [markdown]
# ---
# ## **흑백 이미지 열기**

# %%
plt.imshow(image_bw, 'gray')
plt.show()

# %% [markdown]
# ---
#
# ## **다른 색상으로 cmap 표현하기**
#
# ### **gray scale**

# %%
print(image.shape)
print(image_bw.shape)
# Out:
# (512, 512, 3)
# (512, 512)

# %%
plt.imshow(image_bw, 'gray')
plt.show()

# %% [markdown]
# ---
# ### **RdBu**

# %%
plt.imshow(image_bw, 'RdBu')
plt.show()

# %% [markdown]
# ---
#
# ### **jet**

# %%
plt.imshow(image_bw, 'jet')
plt.show()

# %% [markdown]
# ---
#
# ### **colorbar 추가하기**

# %%
plt.imshow(image_bw, 'jet')
plt.colorbar()
plt.show()

# %% [markdown]
# ## **이미지 설정**
#
# 이미지 보기 사이즈 조절

# %%
plt.figure(figsize=(6, 6))
plt.imshow(image)
plt.colorbar()
plt.show()

# %% [markdown]
# ---
# ## **이미지에 제목 추가**

# %%
plt.title('Su-ji')
plt.imshow(image)
plt.show()

# %% [markdown]
# ---
# ## **두번째 이미지 열기**

# %%
path2 = 'C:/Users/DCU/Desktop/Git-cum/Fast_Cappus_-DeepLearning-AI/인공지능에 대한 기초개념과 준비/image/나연.jpg'

path2_pil = Image.open(path2)
path2_image = np.array(path2_pil)

# %%
plt.imshow(path2_image)
plt.show()

# %% [markdown]
# ---
# ### **두번째 이미지를 첫번째 이미지 모양에 맞추기**

# %%
path2_image.shape
# Out:
# (512, 768, 3)

# %%
image.shape, path2_image.shape
# Out:
# ((512, 512, 3), (512, 768, 3))

# %% [markdown]
# ---
# ### **두번째 이미지 합치기 위한준비**

# %%
import cv2

# %%
path2_image = cv2.resize(path2_image, (512, 512))
path2_image.shape
# Out:
# (512, 512, 3)

# %%
image.shape, path2_image.shape
# Out:
# ((512, 512, 3), (512, 512, 3))

# %% [markdown]
# ### **Image 합치기**

# %%
plt.imshow(image)
plt.imshow(path2_image, alpha = 0.5)
plt.show()

# %% [markdown]
# ----
# ## **Subplot**

# %%
path2_image = cv2.resize(path2_image, (768, 512))

plt.figure(figsize = (10, 10))
plt.subplot(221)
plt.imshow(image)
plt.subplot(222)
plt.imshow(image_bw, 'gray')
plt.subplot(223)
plt.imshow(path2_image)
plt.show()
